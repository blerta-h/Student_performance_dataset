# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("student_data.csv")

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df.shape
# Out:
# (395, 33)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
import seaborn as sns

# %%
sns.set_theme(style='darkgrid')

# %%
sns.countplot(df['school'])
# Out:
# C:\Users\SettingsComputers\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='school', ylabel='count'>

# %%
pd.set_option('display.max_columns',20)
pd.set_option('display.max_rows', 20)

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
schema_df=pd.read_csv('student_data.csv')

# %%
schema_df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df['age']
# Out:
# 0      18
# 1      17
# 2      15
# 3      15
# 4      16
#        ..
# 390    20
# 391    17
# 392    21
# 393    18
# 394    19
# Name: age, Length: 395, dtype: int64

# %%
df.loc[300,'school']
# Out:
# 'GP'

# %%
df.loc[300,'age']
# Out:
# 18

# %%
df.loc[1]
# Out:
# school       GP
# sex           F
# age          17
# address       U
# famsize     GT3
#            ...
# health        3
# absences      4
# G1            5
# G2            5
# G3            6
# Name: 1, Length: 33, dtype: object

# %%
schema_df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
schema_df=pd.read_csv('student_data.csv', index_col= 'age')

# %%
schema_df
# Out:
#     school sex address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# age
# 18      GP   F       U     GT3       A     4     4   at_home   teacher
# 17      GP   F       U     GT3       T     1     1   at_home     other
# 15      GP   F       U     LE3       T     1     1   at_home     other
# 15      GP   F       U     GT3       T     4     2    health  services
# 16      GP   F       U     GT3       T     3     3     other     other
# ..     ...  ..     ...     ...     ...   ...   ...       ...       ...
# 20      MS   M       U     LE3       A     2     2  services  services
# 17      MS   M       U     LE3       T     3     1  services  services
# 21      MS   M       R     GT3       T     1     1     other     other
# 18      MS   M       R     LE3       T     3     2  services     other
# 19      MS   M       U     LE3       T     1     1     other   at_home
#
#      reason  ... famrel  freetime  goout  Dalc Walc health absences  G1  G2  \
# age          ...
# ...

# %%
df['G2'].head(10)
# Out:
# 0     6
# 1     5
# 2     8
# 3    14
# 4    10
# 5    15
# 6    12
# 7     5
# 8    18
# 9    15
# Name: G2, dtype: int64

# %%
df['G2'].tail(10)
# Out:
# 385     9
# 386     5
# 387     5
# 388     9
# 389     5
# 390     9
# 391    16
# 392     8
# 393    12
# 394     9
# Name: G2, dtype: int64

# %%
df['G2'].median()
# Out:
# 11.0

# %%
df.median()
# Out:
# C:\Users\SETTIN~1\AppData\Local\Temp/ipykernel_11640/530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# age           17.0
# Medu           3.0
# Fedu           2.0
# traveltime     1.0
# studytime      2.0
# failures       0.0
# famrel         4.0
# freetime       3.0
# goout          3.0
# Dalc           1.0
# Walc           2.0
# health         4.0
# absences       4.0
# G1            11.0
# G2            11.0
# G3            11.0
# dtype: float64

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
df.groupby(['school'])

# %%
country_groupby = df.groupby(['school'])

# %%
country_groupby.get_group('GP')
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1  at_home     other
# 2       GP   F   15       U     LE3       T     1     1  at_home     other
# 3       GP   F   15       U     GT3       T     4     2   health  services
# 4       GP   F   16       U     GT3       T     3     3    other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...      ...       ...
# 344     GP   F   18       U     GT3       T     2     3  at_home     other
# 345     GP   F   18       U     GT3       T     3     2    other  services
# 346     GP   M   18       R     GT3       T     4     3  teacher  services
# 347     GP   M   18       U     GT3       T     4     3  teacher     other
# 348     GP   F   17       U     GT3       T     4     3   health     other
#
# ...

# %%
filt = df['school'] == 'MIS'

# %%
df.loc[filt]
# Out:
# Empty DataFrame
# Columns: [school, sex, age, address, famsize, Pstatus, Medu, Fedu, Mjob, Fjob, reason, guardian, traveltime, studytime, failures, schoolsup, famsup, paid, activities, nursery, higher, internet, romantic, famrel, freetime, goout, Dalc, Walc, health, absences, G1, G2, G3]
# Index: []
#
# [0 rows x 33 columns]

# %%
filt = df['school'] == 'MS'

# %%
df.loc[filt]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 349     MS   M   18       R     GT3       T     3     2     other     other
# 350     MS   M   19       R     GT3       T     1     1     other  services
# 351     MS   M   17       U     GT3       T     3     3    health     other
# 352     MS   M   18       U     LE3       T     1     3   at_home  services
# 353     MS   M   19       R     GT3       T     1     1     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df.loc[filt]['sex'].value_counts()
# Out:
# F    25
# M    21
# Name: sex, dtype: int64

# %%
df['age'].min()
# Out:
# 15

# %%
df['age'].max()
# Out:
# 22

# %%
df.set_index('freetime')
# Out:
#          school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# freetime
# 3            GP   F   18       U     GT3       A     4     4   at_home
# 3            GP   F   17       U     GT3       T     1     1   at_home
# 3            GP   F   15       U     LE3       T     1     1   at_home
# 2            GP   F   15       U     GT3       T     4     2    health
# 3            GP   F   16       U     GT3       T     3     3     other
# ...         ...  ..  ...     ...     ...     ...   ...   ...       ...
# 5            MS   M   20       U     LE3       A     2     2  services
# 4            MS   M   17       U     LE3       T     3     1  services
# 5            MS   M   21       R     GT3       T     1     1     other
# 4            MS   M   18       R     LE3       T     3     2  services
# 2            MS   M   19       U     LE3       T     1     1     other
#
#               Fjob  ... romantic famrel  goout  Dalc  Walc health absences  \
# freetime            ...
# ...

# %%
df.set_index('goout')
# Out:
#       school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# goout
# 4         GP   F   18       U     GT3       A     4     4   at_home   teacher
# 3         GP   F   17       U     GT3       T     1     1   at_home     other
# 2         GP   F   15       U     LE3       T     1     1   at_home     other
# 2         GP   F   15       U     GT3       T     4     2    health  services
# 2         GP   F   16       U     GT3       T     3     3     other     other
# ...      ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 4         MS   M   20       U     LE3       A     2     2  services  services
# 5         MS   M   17       U     LE3       T     3     1  services  services
# 3         MS   M   21       R     GT3       T     1     1     other     other
# 1         MS   M   18       R     LE3       T     3     2  services     other
# 3         MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
plt.style.use('seaborn')


data = pd.read_csv('student_data.csv')
freetime = data['freetime']
goout = data['goout']
age = data['age']

plt.scatter(freetime, goout, edgecolor='red', linewidth=0.1, alpha=0.75)

plt.title('Studentet')
plt.xlabel('freetime')
plt.ylabel('goout')

plt.show()

# %%
plt.style.use('seaborn')


data = pd.read_csv('student_data.csv')
freetime = data['freetime']
goout = data['goout']
age = data['age']

plt.scatter(freetime, goout, c= ratio, cmap = 'summer', edgecolor='black', linewidth=1, alpha=0.75)

cbar = plt.colorbar()
cbar.set_label('Mosha')

plt.xscale('log')
plt.yscale('log')


plt.title('Studentet')
plt.xlabel('freetime')
plt.ylabel('goout')

plt.show()

# %%
sns.scatterplot(x=df['absences'],y=df['absences'],hue=df['sex'])
# Out:
# <AxesSubplot:xlabel='absences', ylabel='absences'>

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
sns.countplot(df['age'])
# Out:
# C:\Users\SettingsComputers\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='count'>

# %%
sns.countplot(df['health'])
# Out:
# C:\Users\SettingsComputers\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='health', ylabel='count'>

# %%
sns.countplot(df['absences'])
# Out:
# C:\Users\SettingsComputers\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='absences', ylabel='count'>

# %%
data = pd.read_csv('student_data.csv')
plt.title('mediana sipas moshes')
plt.plot(age)
plt.show()

# %%
plt.style.use('ggplot')


data = pd.read_csv('student_data.csv')
freetime = data['freetime']
goout = data['goout']
age = data['age']

plt.scatter(freetime, goout, c= ratio, cmap = 'summer', edgecolor='black', linewidth=1, alpha=0.75)

cbar = plt.colorbar()
cbar.set_label('Mosha')

plt.xscale('log')
plt.yscale('log')


plt.title('Studentet')
plt.xlabel('freetime')
plt.ylabel('goout')

plt.show()

# %%
plt.style.use('fivethirtyeight')


data = pd.read_csv('student_data.csv')
freetime = data['freetime']
goout = data['goout']
age = data['age']

plt.scatter(freetime, goout, linestyle ='--', cmap = 'summer', edgecolor='black', linewidth=1, alpha=0.75)

cbar = plt.colorbar()
cbar.set_label('Mosha')

plt.xscale('log')
plt.yscale('log')


plt.title('Studentet')
plt.xlabel('freetime')
plt.ylabel('goout')

plt.show()
